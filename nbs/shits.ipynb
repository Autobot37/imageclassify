# %% [markdown]
# # Shits on Image Dataset
# ## Author:Shiva Singh Bagri

# %% [markdown]
# **Regular Imports**

# %%
import torch
import torch.nn as nn
from tqdm import tqdm
from sklearn.metrics import confusion_matrix, roc_auc_score
from torchvision.transforms import transforms
from PIL import Image
import os
import numpy as np
from torch.utils.data import DataLoader, SubsetRandomSampler
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix, roc_auc_score
import matplotlib.pyplot as plt
import torchvision.models as models
import torch.nn.functional as F

# %% [markdown]
# **Specifying GPU for acceleration**

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## Data Utilities
# * data augmentation and transforms to prevent overfitting with eg random flip.
# * image size we resizing is (224,224,3)
# * normalising to a mean and standard deviation i specifically choose this mean because this is mean and std from imagenet dataset and a good representative for image datasets.
# [(https://stackoverflow.com/questions/58151507/why-pytorch-officially-use-mean-0-485-0-456-0-406-and-std-0-229-0-224-0-2)]

# %%
class Data(torch.utils.data.Dataset):
    def __init__(self,images,labels):
        super().__init__()
        self.images = images
        self.labels = labels
        self.preprocess = transforms.Compose([
            transforms.RandomHorizontalFlip(),
            transforms.Resize(256),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
        ])
        assert len(self.images)==len(self.labels),"unmatched dataset"
    def __len__(self):
        return len(self.images)
    def __getitem__(self,idx):
        img = Image.open(self.images[idx])
        label = self.labels[idx]
        return self.preprocess(img), torch.tensor(label,dtype=torch.long)

# %% [markdown]
# ## Here is mean data distribution of pixel values of all classes

# %%
img_path = "/kaggle/input/animal-image-dataset-90-different-animals/animals/animals"

pixel_values = []
images = []
for folder in os.listdir(img_path):
    anim_fold = os.path.join(img_path, folder)
    for t, img_file in enumerate(os.listdir(anim_fold)):
        if t>=1:break
        img_path_full = os.path.join(anim_fold, img_file)
        images.append(img_path_full)
  
labels = [-1]*len(images)
temp_data = Data(images=images,labels=labels)
for img,label in temp_data:
    pixel_values.append(img.flatten())

# Plot histogram of pixel values
plt.figure(figsize=(10, 6))
plt.hist(pixel_values, bins=30, alpha=0.7)
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.title('Histogram of Pixel Values')
plt.show()

# %% [markdown]
# ## Train function
# * for every epoch it first trains on train_loader and do a validation on val_loader
# * here we are using tqdm for a progress bar
# * **Default hyperparameters**
# * epochs per fold =: 3
# * learning rate =: 1e-4
# * loss function =: CrossEntropyLoss
# * optimizer =: AdamW with lr = 1e-4 and defaults betas (0.9,0.99) with 0.01 default weight decay

# %% [markdown]
# superconvergence post[https://www.fast.ai/posts/2018-07-02-adam-weight-decay.html]

# %% [markdown]
# **there are some optimizations like:**
# * deleting model at end and saving best weights
# * deleting images and labels sent to gpu at end
# * **Half precision** for validation , since we dont have to update weights here, using half precision makes it fast for fast evaluating.

# %%
def train(train_loader, val_loader, model, epochs=3, lr=1e-4, model_name="model",lossf = nn.CrossEntropyLoss(),best_acc=0.0):
    model.to(device)
    model.train()
    if(os.path.exists(f"{model_name}_model.pth")):
        model.load_state_dict(torch.load(f"{model_name}_model.pth"))  #saving best weights
        print(f"weights of {model_name} loaded")
    optim = torch.optim.AdamW(model.parameters(), lr=lr)
    
    losslist = []
    accuracylist = []
    y_true = []
    y_pred = []
    
    for epoch in range(epochs):
        # Training loop
        total_loss = 0.0
        total_correct = 0
        total_samples = 0
        #progress bar 
        train_progress = tqdm(enumerate(train_loader), total=len(train_loader), desc=f"Epoch {epoch+1}/{epochs} (Training) for {model_name}")
        for batch_idx, (imgs, labels) in train_progress:
            imgs, labels = imgs.to(device), labels.to(device)
            out = model(imgs)
            loss = lossf(out, labels)
            optim.zero_grad(set_to_none=True)
            loss.backward()
            optim.step()
            total_loss += loss.item() 
            _, predicted = torch.max(out.data, 1)
            total_correct += (predicted == labels).sum().item()
            total_samples += labels.size(0)
            loss_now = total_loss / (batch_idx + 1)
            accuracy_now = total_correct / total_samples
            train_progress.set_postfix(loss=loss_now, acc=accuracy_now)
            del imgs, labels
            
        # Validation loop
        total_val_loss = 0.0
        total_val_correct = 0
        total_val_samples = 0
        val_progress = tqdm(enumerate(val_loader), total=len(val_loader), desc=f"Epoch {epoch+1}/{epochs} (Validation) for {model_name}")
        model.eval()
        with torch.no_grad():
            for batch_idx, (imgs, labels) in val_progress:
                imgs, labels = imgs.to(device), labels.to(device)
                with torch.autocast(device_type="cuda"):##Half preicision
                    out = model(imgs)
                    loss = lossf(out, labels)
                total_val_loss += loss.item() 
                _, predicted = torch.max(out.data, 1)
                total_val_correct += (predicted == labels).sum().item()
                total_val_samples += labels.size(0)
                val_loss_now = total_val_loss / (batch_idx + 1)
                val_accuracy_now = total_val_correct / total_val_samples
                val_progress.set_postfix(loss=val_loss_now, acc=val_accuracy_now)
                y_true.extend(labels.cpu().numpy())
                y_pred.extend(predicted.cpu().numpy())
                del imgs, labels
                
        losslist.append(total_val_loss / len(val_loader))
        val_acc = total_val_correct / total_val_samples
        accuracylist.append(val_acc)
        #saving best model
        if val_acc > best_acc:
            best_acc = val_acc
            save(model, f"{model_name}_model.pth")
            print(f"{model_name} weights saved with best accuracy :{best_acc}")
                
        model.train()
        
    del model
    print("Training completed weight saved.")
    return losslist, accuracylist, y_true, y_pred, best_acc

def save(model, path):
    torch.save(model.state_dict(), path)
    print(f"Model saved to {path}")

# %% [markdown]
# ## Main One vs Rest binary classification function
# * Make a train and Validation Dataloader for 3 folds and collect data like loss and accuracy to plot

# %% [markdown]
# ## Dataloader
# * taking images from a particular data index class and other data classes, and for binary classification we set data index class labels as 1 and other labels as 0
# * here take is a parameter which defines how much to take from other classes currently we take 10% of other classes and it works.
# * setting number of workers 2 and pin memory for faster data caching

# %% [markdown]
# **Batch Size**
# * batch size is 16
# * since GPU we are using P100 has enough memory and bottleneck is not gpu but cpu for data caching.

# %%
def one_vs_rest(model,model_name, data_index, n_fold=3,batch_size=16, num_workers=2,img_path = "/kaggle/input/animal-image-dataset-90-different-animals/animals/animals",best_acc=0.0):
    # Data loading
    images = []
    labels = []
    for folder in os.listdir(img_path):
        anim_fold = os.path.join(img_path, folder)
        if folder == os.listdir(img_path)[data_index]:
            take = 1
        else:
            take = 0.25
        tot_len = len(os.listdir(anim_fold))
        for t,img_file in enumerate(os.listdir(anim_fold)):
            if t>=take*tot_len:
                break
            img_path_full = os.path.join(anim_fold, img_file)
            images.append(img_path_full)
            if folder == os.listdir(img_path)[data_index]:
                labels.append(1)
            else:
                labels.append(0)
    images = np.array(images)
    labels = np.array(labels)
    
    # Define dataset and indices
    dataset = Data(images=images, labels=labels)
    kf = KFold(n_splits=n_fold, shuffle=True, random_state=42)
    
    allloss = {"fold1":[],"fold2":[],"fold3":[]}
    allacc = {"fold1":[],"fold2":[],"fold3":[]}
    ally_true = {"fold1":[],"fold2":[],"fold3":[]}
    ally_pred = {"fold1":[],"fold2":[],"fold3":[]}
    

    for fold, (train_indices, val_indices) in enumerate(kf.split(dataset)):
        train_sampler = torch.utils.data.SubsetRandomSampler(train_indices)
        train_loader = DataLoader(dataset, batch_size=batch_size, sampler=train_sampler, num_workers=num_workers, pin_memory=True)

        val_sampler = torch.utils.data.SubsetRandomSampler(val_indices)
        val_loader = DataLoader(dataset, batch_size=batch_size, sampler=val_sampler, num_workers=num_workers, pin_memory=True)

        print(f"Fold {fold+1}:")  
        
        losslist, acclist, y_true, y_pred, best_acc = train(train_loader, val_loader, model,  model_name=model_name, best_acc=best_acc)
        allloss[f"fold{fold+1}"].append(losslist)
        allacc[f"fold{fold+1}"].append(acclist)
        ally_true[f"fold{fold+1}"].append(y_true)
        ally_pred[f"fold{fold+1}"].append(y_pred)
        
    return allloss,allacc,ally_true,ally_pred, best_acc

# %% [markdown]
# ## CustomModel
# * **We used model with AttentionBlock to emphasize the importance of image patches.to focus on important part of images and discared irrelevant parts.although it is helpful in medical datasets but in animal datasets maybe there is a big landscape with animal in small pixels for eg with birds, there attention will be useful.**

# %% [markdown]
# ## *Components*

# %% [markdown]
# # Convolution Blocks
# * There are 5 Conv Blocks each constituting:
# * conv2d batchnorm relu conv2d batchnorm relu and maxpool at the end
# * these convblocks are commonly used.
# * batchnorm is used to stabilise training from covariate shift [https://arxiv.org/abs/1502.03167]
# * ReLU is used as an activation function as used by imagenet paper.
#
# # Hyperparameters
# * kernel size : 3 for Conv filters and :=2 for MaxPooling

# %% [markdown]
# ## Attention Block
# [https://github.com/SaoYan/IPMI2019-AttnMel/blob/99e4a9b71717fb51f24d7994948b6a0e76bb8d58/networks.py]
# * The intermediate features is the output of pool-3 or pool-4 and the global feature vector (output of pool-5) is fed as input to the attention layer.
# * feature upsampling is done via bilinear interpolation to mak intermediate and global feature vector same shape.
# * After that an element wise sum is done followed by a convolution operation that just reduces the 256 channels to 1.
# * This is then fed into a Softmax layer, which gives us a normalized Attention map (A). Each scalar element in A represents the degree of attention to the corresponding spatial feature vector in F.
# * The new feature vector 𝐹̂ is then computed by pixel-wise multiplication. That is, each feature vector f is multiplied by the attention element a
# * So, the attention map A and the new feature vector 𝐹̂ are the outputs of the Attention Layer.

# %% [markdown]
# ## Initialising
# * we initialise with kaiming normal to prevent gradient vanishing or exploding latter on.
#
# * Conv2d Layers: initializes the weights using the Kaiming normal.
#
# * BatchNorm2d Layers: it sets the weights to 1 and biases to 0.
#
# * Linear Layers: initializes the weights from a normal distribution with mean 0 and standard deviation 0.01. It sets the biases to 0.

# %%
class AttentionBlock(nn.Module):
    def __init__(self, in_features_l, in_features_g, attn_features, up_factor, normalize_attn=True):
        super(AttentionBlock, self).__init__()
        self.up_factor = up_factor
        self.normalize_attn = normalize_attn
        self.W_l = nn.Conv2d(in_channels=in_features_l, out_channels=attn_features, kernel_size=1, padding=0, bias=False)
        self.W_g = nn.Conv2d(in_channels=in_features_g, out_channels=attn_features, kernel_size=1, padding=0, bias=False)
        self.phi = nn.Conv2d(in_channels=attn_features, out_channels=1, kernel_size=1, padding=0, bias=True)
    def forward(self, l, g):
        N, C, W, H = l.size()
        l_ = self.W_l(l)
        g_ = self.W_g(g)
        if self.up_factor > 1:
            g_ = F.interpolate(g_, scale_factor=self.up_factor, mode='bilinear', align_corners=False)
        c = self.phi(F.relu(l_ + g_)) # batch_sizex1xWxH
        
        # compute attn map
        if self.normalize_attn:
            a = F.softmax(c.view(N,1,-1), dim=2).view(N,1,W,H)
        else:
            a = torch.sigmoid(c)
        # re-weight the local feature
        f = torch.mul(a.expand_as(l), l) # batch_sizexCxWxH
        if self.normalize_attn:
            output = f.view(N,C,-1).sum(dim=2) # weighted sum
        else:
            output = F.adaptive_avg_pool2d(f, (1,1)).view(N,C) # global average pooling
        return a, output

class Model(nn.Module):
    def __init__(self, num_classes, normalize_attn=False):
        super().__init__()
        self.conv_block1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.conv_block2 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.conv_block3 = nn.Sequential(
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.conv_block4 = nn.Sequential(
            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.conv_block5 = nn.Sequential(
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.pool = nn.AvgPool2d(7, stride=1)
     
        self.cls = nn.Linear(in_features=768, out_features=num_classes, bias=True)
        
       # initialize the attention blocks defined above
        self.attn1 = AttentionBlock(256, 512, 256, 4, normalize_attn=normalize_attn)
               
        self.reset_parameters(self.cls)
        self.reset_parameters(self.attn1)
    
    def reset_parameters(self, module):
        for m in module.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0.)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1.)
                nn.init.constant_(m.bias, 0.)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, 0., 0.01)
                nn.init.constant_(m.bias, 0.)
    
    def forward(self, x):
        block1 = self.conv_block1(x)       # /2
        block2 = self.conv_block2(block1)  # /4
        block3 = self.conv_block3(block2)  # /8
        block4 = self.conv_block4(block3)  # /16
        block5 = self.conv_block5(block4)  # /32
        N, __, __, __ = block5.size()
        
        g = self.pool(block5).view(N,512)
        a1, g1 = self.attn1(block3, block5)
        g_hat = torch.cat((g,g1), dim=1) # batch_size x C
        out = self.cls(g_hat)

        return out

# %%
model = Model(2)
x = torch.randn((8,3,224,224))
model(x)
# Out:
# tensor([[0.0750, 0.3028],
#         [0.0693, 0.3110],
#         [0.0297, 0.3149],
#         [0.0430, 0.3057],
#         [0.0523, 0.3022],
#         [0.0655, 0.3271],
#         [0.0590, 0.3253],
#         [0.0932, 0.3208]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# ## Now we just for every data class perform One vs Rest classification for :
# * **Resnet**
# * **EfficientNet**
# * **CustomModel**

# %% [markdown]
# # Resnet

# %%
##
resnet = torch.hub.load('pytorch/vision:v0.10.0', 'resnet18', pretrained=True)
resnet.fc = nn.Linear(512,2)

allloss = {"fold1":[],"fold2":[],"fold3":[]}
allacc = {"fold1":[],"fold2":[],"fold3":[]}
ally_true = {"fold1":[],"fold2":[],"fold3":[]}
ally_pred = {"fold1":[],"fold2":[],"fold3":[]}

metrics = [allloss,allacc,ally_true,ally_pred]

import time
timer = []

best_acc_resnet = 0.0
n_classes = 5

for data_idx in range(n_classes):
    s = time.time()
    loss,acc,y_true,y_pred,best_acc_resnet = one_vs_rest(resnet,"Resnet_bi",data_idx,best_acc=best_acc_resnet)
    print(f"-------------------data_class:{data_idx+1} completed---------------")
    print(f"time elapsed:{time.time()-s:.2f} seconds")
    timer.append(time.time()-s)
    returned = [loss,acc,y_true,y_pred]
    for i,m in enumerate(metrics):
        for fold in range(3):
            m[f"fold{fold+1}"].append(returned[i][f"fold{fold+1}"])
# Out:
# Downloading: "https://github.com/pytorch/vision/zipball/v0.10.0" to /root/.cache/torch/hub/v0.10.0.zip
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 139MB/s]
# Fold 1:
# Epoch 1/3 (Training) for Resnet_bi: 100%|██████████| 59/59 [00:11<00:00,  5.26it/s, acc=0.768, loss=0.45]
# Epoch 1/3 (Validation) for Resnet_bi: 100%|██████████| 30/30 [00

# Epoch 2/3 (Validation) for Resnet_bi: 100%|██████████| 30/30 [00:04<00:00,  7.46it/s, acc=0.991, loss=0.0239]
# Epoch 3/3 (Training) for Resnet_bi: 100%|██████████| 59/59 [00:07<00:00,  8.22it/s, acc=1, loss=0.00625]
# Epoch 3/3 (Validation) for Resnet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.37it/s, acc=0.989, loss=0.0312]
# Training completed weight saved.
# -------------------data_class:3 completed---------------
# time elapsed:98.77 seconds
# Fold 1:
# weights of Resnet_bi loaded
# Epoch 1/3 (Training) for Resnet_bi: 100%|██████████| 59/59 [00:07<00:00,  7.56it/s, acc=0.969, loss=0.103]
# Epoch 1/3 (Validation) for Resnet_bi: 100%|██████████| 30/30 [00:04<00:00,  7.10it/s, acc=0.987, loss=0.0458]
# Epoch 2/3 (Training) for Resnet_bi: 100%|██████████| 59/59 [00:08<00:00,  7.32it/s, acc=0.992, loss=0.0251]
# Epoch 2/3 (Validation) for Resnet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.50it/s, acc=0.991, loss=0.0326]
# Epoch 3/3 (Training) for Resnet_bi: 100%|██████████| 59/59 [00:07<00:00,  7.93it/s, acc=0.995, loss=0.0316]
# Epoch 3/3 (Validation) for Resnet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.51it/s, acc=0.987, loss=0.0347]
# Training completed weight saved.
# Fold 2:
# weights of Resnet_bi loaded
# Epoch 1/3 (Training) for Resnet_bi: 100%|██████████| 59/59 [00:07<00:00,  7.76it/s, acc=0.973, loss=0.0971]
# Epoch 1/3 (Validation) for Resnet_bi: 100%|██████████| 30/30 [00:04<00:00,  7.43it/s, acc=0.983, loss=0.0549]
# Epoch 2/3 (Training) for Resnet_bi: 100%|██████████| 59/59 [00:07<00:00,  8.30it/s, acc=0.992, loss=0.0245]
# Epoch 2/3 (Validation) for Resnet_bi: 100%|██████████| 30/30 [00:03<00:00,  7.68it/s, acc=0.987, loss=0.0256]
# Epoch 3/3 (Training) for Resnet_bi: 100%|██████████| 59/59 [00:07<00:00,  7.90it/s, acc=0.994, loss=0.0152]
# Epoch 3/3 (Validation) for Resnet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.49it/s, acc=0.976, loss=0.0598]
# Training completed weight saved.
# Fold 3:
# weights of Resnet_bi loaded
# Epoch 1/3 (Training) for Resnet_bi: 100%|██████████| 59/59 [00:07<00:00,  8.09it/s, acc=0.962, loss=0.0927]
# Epoch 1/3 (Validation) for Resnet_bi: 100%|██████████| 30/30 [00:04<00:00,  7.24it/s, acc=0.989, loss=0.0383]
# Epoch 2/3 (Training) for Resnet_bi: 100%|██████████| 59/59 [00:07<00:00,  8.25it/s, acc=0.992, loss=0.0261]
# Epoch 2/3 (Validation) for Resnet_bi: 100%|██████████| 30/30 [00:03<00:00,  7.66it/s, acc=0.955, loss=0.0997]
# Epoch 3/3 (Training) for Resnet_bi: 100%|██████████| 59/59 [00:07<00:00,  8.19it/s, acc=0.996, loss=0.0168]
# Epoch 3/3 (Validation) for Resnet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.44it/s, acc=0.985, loss=0.058]
# Training completed weight saved.
# -------------------data_class:4 completed---------------
# time elapsed:103.50 seconds
# Fold 1:
# weights of Resnet_bi loaded
# Epoch 1/3 (Training) for Resnet_bi: 100%|██████████| 59/59 [00:07<00:00,  7.40it/s, acc=0.973, loss=0.0806]
# Epoch 1/3 (Validation) for Resnet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.81it/s, acc=0.991, loss=0.0208]
# Epoch 2/3 (Training) for Resnet_bi: 100%|██████████| 59/59 [00:07<00:00,  7.96it/s, acc=0.995, loss=0.0136]
# Epoch 2/3 (Validation) for Resnet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.96it/s, acc=0.987, loss=0.0229]
# Epoch 3/3 (Training) for Resnet_bi: 100%|██████████| 59/59 [00:07<00:00,  8.11it/s, acc=0.996, loss=0.0135]
# Epoch 3/3 (Validation) for Resnet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.19it/s, acc=0.989, loss=0.0213]
# Training completed weight saved.
# Fold 2:
# weights of Resnet_bi loaded
# Epoch 1/3 (Training) for Resnet_bi: 100%|██████████| 59/59 [00:07<00:00,  8.12it/s, acc=0.977, loss=0.0697]
# Epoch 1/3 (Validation) for Resnet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.20it/s, acc=0.981, loss=0.0338]
# Epoch 2/3 (Training) for Resnet_bi: 100%|██████████| 59/59 [00:06<00:00,  8.65it/s, acc=0.998, loss=0.0137]
# Epoch 2/3 (Validation) for Resnet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.50it/s, acc=0.981, loss=0.0567]
# Epoch 3/3 (Training) for Resnet_bi: 100%|██████████| 59/59 [00:07<00:00,  7.94it/s, acc=0.994, loss=0.0131]
# Epoch 3/3 (Validation) for Resnet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.58it/s, acc=0.981, loss=0.0926]
# Training completed weight saved.
# Fold 3:
# weights of Resnet_bi loaded
# Epoch 1/3 (Training) for Resnet_bi: 100%|██████████| 59/59 [00:07<00:00,  7.94it/s, acc=0.968, loss=0.0833]
# Epoch 1/3 (Validation) for Resnet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.70it/s, acc=0.994, loss=0.0213]
# Epoch 2/3 (Training) for Resnet_bi: 100%|██████████| 59/59 [00:07<00:00,  8.40it/s, acc=0.999, loss=0.0126]
# Epoch 2/3 (Validation) for Resnet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.15it/s, acc=0.996, loss=0.0209]
# Epoch 3/3 (Training) for Resnet_bi: 100%|██████████| 59/59 [00:07<00:00,  8.39it/s, acc=1, loss=0.00327]
# Epoch 3/3 (Validation) for Resnet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.18it/s, acc=0.998, loss=0.0103]
# Training completed weight saved.
# -------------------data_class:5 completed---------------
# time elapsed:99.52 seconds

# %% [markdown]
# ## Since 90 classes are lot, we will plot foldwise mean of loss accuracy and confusion matrix
# ## Resnet Plots

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_curve, roc_auc_score

def plot_loss(allloss):
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    for i in range(3):
        axs[i].plot(np.mean(allloss[f"fold{i+1}"],axis=0)[0], label=f"{fold+1} fold",c='red')
        axs[i].set_title(f'Fold {i+1} Validation Mean Loss')  
        axs[i].set_xlabel('Epochs/fold')
        axs[i].set_ylabel('Loss')
        axs[i].legend()
    plt.tight_layout()  
    plt.show()

def plot_acc(allacc):
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    for i in range(3):
        axs[i].plot(np.mean(allacc[f"fold{i+1}"],axis=0)[0], label=f"{fold+1} fold",c='orange')
        axs[i].set_title(f'Fold {i+1} Validation Mean Accuracy')  
        axs[i].set_xlabel('Epochs/fold')
        axs[i].set_ylabel('Loss')
        axs[i].legend()
    plt.tight_layout()  
    plt.show()

def plot_cm(all_y_true, all_y_pred):
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    for fold in range(3):    
        real = []
        for i in range(len(ally_true[f"fold{fold+1}"])):
            real.extend(ally_true[f"fold{fold+1}"][i][0])
        pred = []
        for i in range(len(ally_pred[f"fold{fold+1}"])):
            pred.extend(ally_pred[f"fold{fold+1}"][i][0])
        cm = confusion_matrix(real, pred)
        ConfusionMatrixDisplay(cm).plot(ax=axs[fold],cmap='Blues',values_format='d')
        axs[fold].set_title(f"Fold {fold+1}")
    plt.tight_layout()
    plt.show()
plot_loss(allloss)
plot_acc(allacc)
plot_cm(ally_true,ally_pred)

# %% [markdown]
# # EfficientNet b0

# %%
##
efficientnet = models.efficientnet_b0(pretrained=True)
efficientnet.classifier[1] = nn.Linear(1280,2)

allloss = {"fold1":[],"fold2":[],"fold3":[]}
allacc = {"fold1":[],"fold2":[],"fold3":[]}
ally_true = {"fold1":[],"fold2":[],"fold3":[]}
ally_pred = {"fold1":[],"fold2":[],"fold3":[]}

metrics = [allloss,allacc,ally_true,ally_pred]

import time
timee = []

best_acc_eff = 0.0
n_classes = 5
for data_idx in range(n_classes):
    s = time.time()
    loss,acc,y_true,y_pred,best_acc_eff = one_vs_rest(efficientnet,"EfficientNet_bi",data_idx,best_acc=best_acc_eff)
    print(f"-------------------data_class:{data_idx+1} completed---------------")
    print(f"time elapsed:{time.time()-s:.2f} seconds")
    timee.append(time.time()-s)
    returned = [loss,acc,y_true,y_pred]
    for i,m in enumerate(metrics):
        for fold in range(3):
            m[f"fold{fold+1}"].append(returned[i][f"fold{fold+1}"])
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 55.0MB/s]
# Fold 1:
# Epoch 1/3 (Training) for EfficientNet_bi: 100%|██████████| 59/59 [00:07<00:00,  7.63it/s, acc=0.928, loss=0.334]
# Epoch 1/3 (Validation) for EfficientNet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.78it/s, acc=0.974, loss=0.178]
# Model saved to EfficientNet_bi_model.pth
# EfficientNet_bi weights saved with best accuracy :0.9741935483870968
# Epoch 2/3 (Training) for EfficientNet_bi: 100%|██████████| 59/59 [00:07<00:00,  8.01it/s, acc=0.987, loss=0.0908]
# Epoch 2/3 (Validation) for EfficientNet_bi: 100%|██████████| 30/30 [00:03<00:00,  9.20it/s, acc=0.991, loss=0.0961]
# Model saved to EfficientNet_bi_model.pth
# EfficientNet_bi weights saved with best accuracy :0.9913978494623656
# Epoch 3/3 (Training) for EfficientNet_bi: 100%|██████████| 59/59 [00:08<00:00,  7.23it/s, acc=0.995, loss=0.0538]
# Epoch 3/3 (Validation) for EfficientNet_bi: 100%|██████████| 30/30 [00:03<00:00,  9.73it/s, acc=0.991, loss=0.0718]
# Training completed weight saved.
# Fold 2:
# weights of EfficientNet_bi loaded
# Epoch 1/3 (Training) for EfficientNet_bi: 100%|██████████| 59/59 [00:07<00:00,  8.39it/s, acc=0.987, loss=0.0442]
# Epoch 1/3 (Validation) for EfficientNet_bi: 100%|██████████| 30/30 [00:03<00:00,  9.12it/s, acc=0.996, loss=0.0365]
# Model saved to EfficientNet_bi_model.pth
# EfficientNet_bi weights saved with best accuracy :0.9956989247311828
# Epoch 2/3 (Training) for EfficientNet_bi: 100%|██████████| 59/59 [00:07<00:00,  7.80it/s, acc=0.998, loss=0.0166]
# Epoch 2/3 (Validation) for EfficientNet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.93it/s, acc=0.996, loss=0.0276]
# Epoch 3/3 (Training) for EfficientNet_bi: 100%|██████████| 59/59 [00:07<00:00,  7.88it/s, acc=1, loss=0.00556]
# Epoch 3/3 (Validation) for EfficientNet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.58it/s, acc=0.996, loss=0.0273]
# Training completed weight saved.
# Fold 3:
# weights of EfficientNet_bi loaded
# Epoch 1/3 (Training) for EfficientNet_bi: 100%|██████████| 59/59 [00:07<00:00,  7.59it/s, acc=0.995, loss=0.0165]
# Epoch 1/3 (Validation) for EfficientNet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.69it/s, acc=0.996, loss=0.0297]
# Epoch 2/3 (Training) for EfficientNet_bi: 100%|██████████| 59/59 [00:07<00:00,  7.77it/s, acc=0.998, loss=0.0157]
# Epoch 2/3 (Validation) for EfficientNet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.25it/s, acc=0.998, loss=0.0163]
# Model saved to EfficientNet_bi_model.pth
# EfficientNet_bi weights saved with best accuracy :0.9978494623655914
# Epoch 3/3 (Training) for EfficientNet_bi: 100%|██████████| 59/59 [00:07<00:00,  7.65it/s, acc=0.999, loss=0.00483]
# Epoch 3/3 (Validation) for EfficientNet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.42it/s, acc=0.998, loss=0.0136]
# Training completed weight saved.
# -------------------data_class:1 completed---------------
# time elapsed:101.31 seconds
# Fold 1:
# weights of EfficientNet_bi loaded
# Epoch 1/3 (Training) for EfficientNet_bi: 100%|██████████| 59/59 [00:07<00:00,  7.72it/s, acc=0.955, loss=0.186]
# Epoch 1/3 (Validation) for EfficientNet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.70it/s, acc=0.987, loss=0.057]
# Epoch 2/3 (Training) for EfficientNet_bi: 100%|██████████| 59/59 [00:07<00:00,  7.67it/s, acc=0.986, loss=0.04]
# Epoch 2/3 (Validation) for EfficientNet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.52it/s, acc=0.994, loss=0.0322]
# Epoch 3/3 (Training) for EfficientNet_bi: 100%|██████████| 59/59 [00:08<00:00,  7.34it/s, acc=0.995, loss=0.0204]
# Epoch 3/3 (Validation) for EfficientNet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.60it/s, acc=0.991, loss=0.0316]
# Training completed weight saved.
# Fold 2:
# weights of EfficientNet_bi loaded
# Epoch 1/3 (Training) for EfficientNet_bi: 100%|██████████| 59/59 [00:07<00:00,  7.88it/s, acc=0.962, loss=0.14]
# Epoch 1/3 (Validation) for EfficientNet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.46it/s, acc=0.957, loss=0.115]
# Epoch 2/3 (Training) for EfficientNet_bi: 100%|██████████| 59/59 [00:07<00:00,  8

# Epoch 3/3 (Validation) for EfficientNet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.61it/s, acc=0.966, loss=0.0743]
# Training completed weight saved.
# Fold 3:
# weights of EfficientNet_bi loaded
# Epoch 1/3 (Training) for EfficientNet_bi: 100%|██████████| 59/59 [00:07<00:00,  7.82it/s, acc=0.959, loss=0.182]
# Epoch 1/3 (Validation) for EfficientNet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.28it/s, acc=0.978, loss=0.0793]
# Epoch 2/3 (Training) for EfficientNet_bi: 100%|██████████| 59/59 [00:07<00:00,  7.87it/s, acc=0.989, loss=0.035]
# Epoch 2/3 (Validation) for EfficientNet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.78it/s, acc=0.985, loss=0.0536]
# Epoch 3/3 (Training) for EfficientNet_bi: 100%|██████████| 59/59 [00:07<00:00,  7.69it/s, acc=0.998, loss=0.0165]
# Epoch 3/3 (Validation) for EfficientNet_bi: 100%|██████████| 30/30 [00:03<00:00,  8.44it/s, acc=0.987, loss=0.0493]
# Training completed weight saved.
# -------------------data_class:5 completed---------------
# time elapsed:102.90 seconds

# %% [markdown]
# # EfficientNet Plots

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_curve, roc_auc_score

def plot_loss(allloss):
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    for i in range(3):
        axs[i].plot(np.mean(allloss[f"fold{i+1}"],axis=0)[0], label=f"{fold+1} fold",c='red')
        axs[i].set_title(f'Fold {i+1} Validation Mean Loss')  
        axs[i].set_xlabel('Epochs/fold')
        axs[i].set_ylabel('Loss')
        axs[i].legend()
    plt.tight_layout()  
    plt.show()

def plot_acc(allacc):
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    for i in range(3):
        axs[i].plot(np.mean(allacc[f"fold{i+1}"],axis=0)[0], label=f"{fold+1} fold",c='orange')
        axs[i].set_title(f'Fold {i+1} Validation Mean Accuracy')  
        axs[i].set_xlabel('Epochs/fold')
        axs[i].set_ylabel('Loss')
        axs[i].legend()
    plt.tight_layout()  
    plt.show()

def plot_cm(all_y_true, all_y_pred):
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    for fold in range(3):    
        real = []
        for i in range(len(ally_true[f"fold{fold+1}"])):
            real.extend(ally_true[f"fold{fold+1}"][i][0])
        pred = []
        for i in range(len(ally_pred[f"fold{fold+1}"])):
            pred.extend(ally_pred[f"fold{fold+1}"][i][0])
        cm = confusion_matrix(real, pred)
        ConfusionMatrixDisplay(cm).plot(ax=axs[fold],cmap='Blues',values_format='d')
        axs[fold].set_title(f"Fold {fold+1}")
    plt.tight_layout()
    plt.show()
plot_loss(allloss)
plot_acc(allacc)
plot_cm(ally_true,ally_pred)

# %% [markdown]
# ## CustomModel

# %%
##
allloss = {"fold1":[],"fold2":[],"fold3":[]}
allacc = {"fold1":[],"fold2":[],"fold3":[]}
ally_true = {"fold1":[],"fold2":[],"fold3":[]}
ally_pred = {"fold1":[],"fold2":[],"fold3":[]}

metrics = [allloss,allacc,ally_true,ally_pred]

import time
timec = []

best_acc_cust = 0.0
n_classes = 5
for data_idx in range(n_classes):
    s = time.time()
    loss,acc,y_true,y_pred,best_acc_cust = one_vs_rest(model,"CustomAttModel_bi",data_idx,best_acc=best_acc_cust)
    print(f"-------------------data_class:{data_idx+1} completed---------------")
    print(f"time elapsed:{time.time()-s:.2f} seconds")
    timec.append(time.time()-s)
    returned = [loss,acc,y_true,y_pred]
    for i,m in enumerate(metrics):
        for fold in range(3):
            m[f"fold{fold+1}"].append(returned[i][f"fold{fold+1}"])
# Out:
# Fold 1:
# Epoch 1/3 (Training) for CustomAttModel_bi: 100%|██████████| 59/59 [00:08<00:00,  6.80it/s, acc=0.928, loss=0.223]
# Epoch 1/3 (Validation) for CustomAttModel_bi: 100%|██████████| 30/30 [00:03<00:00,  8.23it/s, acc=0.968, loss=0.141]
# Model saved to CustomAttModel_bi_model.pth
# CustomAttModel_bi weights saved with best accuracy :0.967741935483871
# Epoch 2/3 (Training) for CustomAttModel_bi: 100%|██████████| 59/59 [00:08<00:00,  6.81it/s, acc=0.949, loss=0.186]
# Epoch 2/3 (Validation) for CustomAttModel_bi: 100%|██████████| 30/30 [00:03<00:00,  8.59it/s, acc=0.944, loss=0.232]
# Epoch 3/3 (Training) for CustomAttModel_bi: 100%|██████████| 59/59 [00:08<00:00,  6.74it/s, acc=0.953, loss=0.172]
# Epoch 3/3 (Validation) for CustomAttModel_bi: 100%|██████████| 30/30 [00:03<00:00,  8.79it/s, acc=0.948, loss=0.138]
# Training completed weight saved.
# Fold 2:
# weights of CustomAttModel_bi loaded
# Epoch 1/3 (Training) for CustomAttModel_bi: 100%|██████████| 59/59 [00:08<00:00,  6.76it/s, acc=0.96, loss=0.173]
# Epoch 1/3 (Validation) for CustomAttModel_bi: 100%|██████████| 30/30 [00:03<00:00,  8.38it/s, acc=0.951, loss=0.195]
# Epoch 2/3 (Training) for CustomAttModel_bi: 100%|██████████| 59/59 [00:08<00:00,  6.89it/s, acc=0.96, loss=0.158]
# Epoch 2/3 (Validation) for CustomAttModel_bi: 100%|██████████| 30/30 [00:04<00:00,  7.44it/s, acc=0.951, loss=0.283]
# Epoch 3/3 (Training) for CustomAttModel_bi: 100%|██████████| 59/59 [00:08<00:00,  6.93it/s, acc=0.96, loss=0.142]
# Epoch 3/3 (Validation) for CustomAttModel_bi: 100%|██████████| 30/30 [00:03<00:00,  8

# Epoch 1/3 (Validation) for CustomAttModel_bi: 100%|██████████| 30/30 [00:03<00:00,  8.56it/s, acc=0.97, loss=0.113]
# Epoch 2/3 (Training) for CustomAttModel_bi: 100%|██████████| 59/59 [00:08<00:00,  6.80it/s, acc=0.951, loss=0.166]
# Epoch 2/3 (Validation) for CustomAttModel_bi: 100%|██████████| 30/30 [00:04<00:00,  7.27it/s, acc=0.97, loss=0.167]
# Epoch 3/3 (Training) for CustomAttModel_bi: 100%|██████████| 59/59 [00:08<00:00,  6.77it/s, acc=0.951, loss=0.172]
# Epoch 3/3 (Validation) for CustomAttModel_bi: 100%|██████████| 30/30 [00:03<00:00,  7.99it/s, acc=0.97, loss=0.181]
# Training completed weight saved.
# -------------------data_class:4 completed---------------
# time elapsed:114.78 seconds
# Fold 1:
# weights of CustomAttModel_bi loaded
# Epoch 1/3 (Training) for CustomAttModel_bi: 100%|██████████| 59/59 [00:09<00:00,  6.55it/s, acc=0.954, loss=0.172]
# Epoch 1/3 (Validation) for CustomAttModel_bi: 100%|██████████| 30/30 [00:03<00:00,  7.95it/s, acc=0.731, loss=1.16]
# Epoch 2/3 (Training) for CustomAttModel_bi: 100%|██████████| 59/59 [00:09<00:00,  6.53it/s, acc=0.951, loss=0.15]
# Epoch 2/3 (Validation) for CustomAttModel_bi: 100%|██████████| 30/30 [00:03<00:00,  8.57it/s, acc=0.783, loss=0.515]
# Epoch 3/3 (Training) for CustomAttModel_bi: 100%|██████████| 59/59 [00:08<00:00,  6.74it/s, acc=0.957, loss=0.123]
# Epoch 3/3 (Validation) for CustomAttModel_bi: 100%|██████████| 30/30 [00:03<00:00,  7.77it/s, acc=0.97, loss=0.102]
# Training completed weight saved.
# Fold 2:
# weights of CustomAttModel_bi loaded
# Epoch 1/3 (Training) for CustomAttModel_bi: 100%|██████████| 59/59 [00:08<00:00,  6.76it/s, acc=0.965, loss=0.156]
# Epoch 1/3 (Validation) for CustomAttModel_bi: 100%|██████████| 30/30 [00:03<00:00,  7.76it/s, acc=0.942, loss=0.189]
# Epoch 2/3 (Training) for CustomAttModel_bi: 100%|██████████| 59/59 [00:08<00:00,  6.97it/s, acc=0.963, loss=0.143]
# Epoch 2/3 (Validation) for CustomAttModel_bi: 100%|██████████| 30/30 [00:03<00:00,  7.81it/s, acc=0.942, loss=0.172]
# Epoch 3/3 (Training) for CustomAttModel_bi: 100%|██████████| 59/59 [00:09<00:00,  6.37it/s, acc=0.962, loss=0.124]
# Epoch 3/3 (Validation) for CustomAttModel_bi: 100%|██████████| 30/30 [00:03<00:00,  7.55it/s, acc=0.886, loss=0.285]
# Training completed weight saved.
# Fold 3:
# weights of CustomAttModel_bi loaded
# Epoch 1/3 (Training) for CustomAttModel_bi: 100%|██████████| 59/59 [00:08<00:00,  6.81it/s, acc=0.952, loss=0.18]
# Epoch 1/3 (Validation) for CustomAttModel_bi: 100%|██████████| 30/30 [00:03<00:00,  8.21it/s, acc=0.968, loss=0.116]
# Epoch 2/3 (Training) for CustomAttModel_bi: 100%|██████████| 59/59 [00:09<00:00,  6.53it/s, acc=0.948, loss=0.171]
# Epoch 2/3 (Validation) for CustomAttModel_bi: 100%|██████████| 30/30 [00:04<00:00,  7.20it/s, acc=0.968, loss=0.123]
# Epoch 3/3 (Training) for CustomAttModel_bi: 100%|██████████| 59/59 [00:08<00:00,  6.86it/s, acc=0.954, loss=0.148]
# Epoch 3/3 (Validation) for CustomAttModel_bi: 100%|██████████| 30/30 [00:03<00:00,  8.16it/s, acc=0.933, loss=0.191]
# Training completed weight saved.
# -------------------data_class:5 completed---------------
# time elapsed:115.96 seconds

# %% [markdown]
# # CustomModel Plots

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_curve, roc_auc_score

def plot_loss(allloss):
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    for i in range(3):
        axs[i].plot(np.mean(allloss[f"fold{i+1}"],axis=0)[0], label=f"{fold+1} fold",c='red')
        axs[i].set_title(f'Fold {i+1} Validation Mean Loss')  
        axs[i].set_xlabel('Epochs/fold')
        axs[i].set_ylabel('Loss')
        axs[i].legend()
    plt.tight_layout()  
    plt.show()

def plot_acc(allacc):
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    for i in range(3):
        axs[i].plot(np.mean(allacc[f"fold{i+1}"],axis=0)[0], label=f"{fold+1} fold",c='orange')
        axs[i].set_title(f'Fold {i+1} Validation Mean Accuracy')  
        axs[i].set_xlabel('Epochs/fold')
        axs[i].set_ylabel('Loss')
        axs[i].legend()
    plt.tight_layout()  
    plt.show()

def plot_cm(all_y_true, all_y_pred):
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    for fold in range(3):    
        real = []
        for i in range(len(ally_true[f"fold{fold+1}"])):
            real.extend(ally_true[f"fold{fold+1}"][i][0])
        pred = []
        for i in range(len(ally_pred[f"fold{fold+1}"])):
            pred.extend(ally_pred[f"fold{fold+1}"][i][0])
        cm = confusion_matrix(real, pred)
        ConfusionMatrixDisplay(cm).plot(ax=axs[fold],cmap='Blues',values_format='d')
        axs[fold].set_title(f"Fold {fold+1}")
    plt.tight_layout()
    plt.show()
plot_loss(allloss)
plot_acc(allacc)
plot_cm(ally_true,ally_pred)

# %% [markdown]
# ## Comparing Best Accuracy on Validation

# %%
models = ["resnet", "efficientnet", "custom"]
accuracies = [best_acc_resnet, best_acc_eff, best_acc_cust]

# Define a colormap
colors = ["orange","blue","red"]

plt.figure(figsize=(6, 6))
bars = plt.bar(models, accuracies, color=colors)

plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison of Different Models')

# Adding the accuracy values on top of the bars
for bar, accuracy in zip(bars, accuracies):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.005, f'{accuracy:.2f}', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Time Taken

# %%
models = ["resnet", "efficientnet", "custom"]
time = [np.sum(timer), np.sum(timee), np.sum(timec)]

# Define a colormap
colors = ["orange","blue","red"]

plt.figure(figsize=(6, 6))
bars = plt.bar(models, time, color=colors)

plt.xlabel('Models')
plt.ylabel('Time in Seconds')
plt.title('Time taken for Different Models')

for bar, time in zip(bars, time):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.005, f'{time:.2f}', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Five class classification

# %% [markdown]
# # in here, we have taken 5 - 5 classes, means 16 parts of 90 class dataset each containing 5 classes and perfomed classification.

# %%
def five_class_classify(model,model_name, data_index, n_fold=3,batch_size=32, num_workers=2,img_path = "/kaggle/input/animal-image-dataset-90-different-animals/animals/animals",best_acc=0.0):
    # Data loading
    images = []
    labels = []
    for offset,folder in enumerate(os.listdir(img_path)[data_index*5:data_index*5+5]):
        anim_fold = os.path.join(img_path, folder)
        for img_file in os.listdir(anim_fold):
            img_path_full = os.path.join(anim_fold, img_file)
            images.append(img_path_full)
            labels.append(offset)
            
    images = np.array(images)
    labels = np.array(labels)
    
    # Define dataset and indices
    dataset = Data(images=images, labels=labels)
    kf = KFold(n_splits=n_fold, shuffle=True, random_state=42)
    
    allloss = {"fold1":[],"fold2":[],"fold3":[]}
    allacc = {"fold1":[],"fold2":[],"fold3":[]}
    ally_true = {"fold1":[],"fold2":[],"fold3":[]}
    ally_pred = {"fold1":[],"fold2":[],"fold3":[]}
    

    for fold, (train_indices, val_indices) in enumerate(kf.split(dataset)):
        train_sampler = torch.utils.data.SubsetRandomSampler(train_indices)
        train_loader = DataLoader(dataset, batch_size=batch_size, sampler=train_sampler, num_workers=num_workers, pin_memory=True)

        val_sampler = torch.utils.data.SubsetRandomSampler(val_indices)
        val_loader = DataLoader(dataset, batch_size=batch_size, sampler=val_sampler, num_workers=num_workers, pin_memory=True)

        print(f"Fold {fold+1}:")  
        
        losslist, acclist, y_true, y_pred, best_acc = train(train_loader, val_loader, model,  model_name=model_name, best_acc=best_acc)
        allloss[f"fold{fold+1}"].append(losslist)
        allacc[f"fold{fold+1}"].append(acclist)
        ally_true[f"fold{fold+1}"].append(y_true)
        ally_pred[f"fold{fold+1}"].append(y_pred)
        
    return allloss,allacc,ally_true,ally_pred, best_acc

# %% [markdown]
# # Resnet

# %%
##
resnet = torch.hub.load('pytorch/vision:v0.10.0', 'resnet18', pretrained=True)
resnet.fc = nn.Linear(512,5)

allloss = {"fold1":[],"fold2":[],"fold3":[]}
allacc = {"fold1":[],"fold2":[],"fold3":[]}
ally_true = {"fold1":[],"fold2":[],"fold3":[]}
ally_pred = {"fold1":[],"fold2":[],"fold3":[]}

metrics = [allloss,allacc,ally_true,ally_pred]

import time
timer = []

best_acc_resnet = 0.0
n_classes = 5
for data_idx in range(5):
    s = time.time()
    loss,acc,y_true,y_pred,best_acc_resnet = one_vs_rest(resnet,"Resnet_five",data_idx,best_acc=best_acc_resnet)
    print(f"-------------------data_class:{data_idx+1} completed---------------")
    print(f"time elapsed:{time.time()-s:.2f} seconds")
    timer.append(time.time()-s)
    returned = [loss,acc,y_true,y_pred]
    for i,m in enumerate(metrics):
        for fold in range(3):
            m[f"fold{fold+1}"].append(returned[i][f"fold{fold+1}"])
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Fold 1:
# Epoch 1/3 (Training) for Resnet_five: 100%|██████████| 59/59 [00:07<00:00,  8.29it/s, acc=0.784, loss=0.713]
# Epoch 1/3 (Validation) for Resnet_five: 100%|██████████| 30/30 [00:03<00:00,  8.70it/s, acc=0.994, loss=0.118]
# Model saved to Resnet_five_model.pth
# Resnet_five weights saved with best accuracy :0.9935483870967742
# Epoch 2/3 (Training) for Resnet_five: 100%|██████████| 59/59 [00:07<00:00,  7.77it/s, acc=0.991, loss=0.0808]
# Epoch 2/3 (Validation) for Resnet_five: 100%|██████████| 30/30 [00:03<00:00,

# Epoch 3/3 (Validation) for Resnet_five: 100%|██████████| 30/30 [00:03<00:00,  8.79it/s, acc=0.989, loss=0.0351]
# Training completed weight saved.
# Fold 2:
# weights of Resnet_five loaded
# Epoch 1/3 (Training) for Resnet_five: 100%|██████████| 59/59 [00:07<00:00,  8.39it/s, acc=0.975, loss=0.0886]
# Epoch 1/3 (Validation) for Resnet_five: 100%|██████████| 30/30 [00:03<00:00,  7.83it/s, acc=0.976, loss=0.0464]
# Epoch 2/3 (Training) for Resnet_five: 100%|██████████| 59/59 [00:07<00:00,  8.16it/s, acc=0.997, loss=0.0176]
# Epoch 2/3 (Validation) for Resnet_five: 100%|██████████| 30/30 [00:03<00:00,  8.23it/s, acc=0.963, loss=0.0812]
# Epoch 3/3 (Training) for Resnet_five: 100%|██████████| 59/59 [00:06<00:00,  8.71it/s, acc=0.997, loss=0.0107]
# Epoch 3/3 (Validation) for Resnet_five: 100%|██████████| 30/30 [00:03<00:00,  8.50it/s, acc=0.961, loss=0.108]
# Training completed weight saved.
# Fold 3:
# weights of Resnet_five loaded
# Epoch 1/3 (Training) for Resnet_five: 100%|██████████| 59/59 [00:07<00:00,  7.87it/s, acc=0.965, loss=0.109]
# Epoch 1/3 (Validation) for Resnet_five: 100%|██████████| 30/30 [00:03<00:00,  8.01it/s, acc=0.983, loss=0.0436]
# Epoch 2/3 (Training) for Resnet_five: 100%|██████████| 59/59 [00:07<00:00,  8.19it/s, acc=0.991, loss=0.0213]
# Epoch 2/3 (Validation) for Resnet_five: 100%|██████████| 30/30 [00:03<00:00,  7.85it/s, acc=0.966, loss=0.078]
# Epoch 3/3 (Training) for Resnet_five: 100%|██████████| 59/59 [00:07<00:00,  8.15it/s, acc=0.998, loss=0.00906]
# Epoch 3/3 (Validation) for Resnet_five: 100%|██████████| 30/30 [00:03<00:00,  8.23it/s, acc=0.976, loss=0.0542]
# Training completed weight saved.
# -------------------data_class:4 completed---------------
# time elapsed:99.03 seconds
# Fold 1:
# weights of Resnet_five loaded
# Epoch 1/3 (Training) for Resnet_five: 100%|██████████| 59/59 [00:07<00:00,  7.75it/s, acc=0.968, loss=0.0903]
# Epoch 1/3 (Validation) for Resnet_five: 100%|██████████| 30/30 [00:03<00:00,  9.37it/s, acc=0.987, loss=0.0268]
# Epoch 2/3 (Training) for Resnet_five: 100%|██████████| 59/59 [00:07<00:00,  8.18it/s, acc=0.996, loss=0.0189]
# Epoch 2/3 (Validation) for Resnet_five: 100%|██████████| 30/30 [00:03<00:00,  9.12it/s, acc=0.985, loss=0.0447]
# Epoch 3/3 (Training) for Resnet_five: 100%|██████████| 59/59 [00:07<00:00,  8.04it/s, acc=0.999, loss=0.00844]
# Epoch 3/3 (Validation) for Resnet_five: 100%|██████████| 30/30 [00:03<00:00,  9.04it/s, acc=0.991, loss=0.0231]
# Training completed weight saved.
# Fold 2:
# weights of Resnet_five loaded
# Epoch 1/3 (Training) for Resnet_five: 100%|██████████| 59/59 [00:07<00:00,  8.27it/s, acc=0.985, loss=0.0603]
# Epoch 1/3 (Validation) for Resnet_five: 100%|██████████| 30/30 [00:03<00:00,  8.50it/s, acc=0.987, loss=0.0434]
# Epoch 2/3 (Training) for Resnet_five: 100%|██████████| 59/59 [00:07<00:00,  8.24it/s, acc=0.998, loss=0.0133]
# Epoch 2/3 (Validation) for Resnet_five: 100%|██████████| 30/30 [00:03<00:00,  7.80it/s, acc=0.974, loss=0.279]
# Epoch 3/3 (Training) for Resnet_five: 100%|██████████| 59/59 [00:06<00:00,  8.75it/s, acc=0.999, loss=0.00456]
# Epoch 3/3 (Validation) for Resnet_five: 100%|██████████| 30/30 [00:03<00:00,  7.96it/s, acc=0.976, loss=0.0533]
# Training completed weight saved.
# Fold 3:
# weights of Resnet_five loaded
# Epoch 1/3 (Training) for Resnet_five: 100%|██████████| 59/59 [00:07<00:00,  8.12it/s, acc=0.971, loss=0.0843]
# Epoch 1/3 (Validation) for Resnet_five: 100%|██████████| 30/30 [00:03<00:00,  8.06it/s, acc=0.991, loss=0.0227]
# Epoch 2/3 (Training) for Resnet_five: 100%|██████████| 59/59 [00:07<00:00,  8.26it/s, acc=0.996, loss=0.0201]
# Epoch 2/3 (Validation) for Resnet_five: 100%|██████████| 30/30 [00:03<00:00,  8.83it/s, acc=1, loss=0.00764]
# Model saved to Resnet_five_model.pth
# Resnet_five weights saved with best accuracy :1.0
# Epoch 3/3 (Training) for Resnet_five: 100%|██████████| 59/59 [00:07<00:00,  8.07it/s, acc=0.998, loss=0.00793]
# Epoch 3/3 (Validation) for Resnet_five: 100%|██████████| 30/30 [00:03<00:00,  7.54it/s, acc=0.998, loss=0.00924]
# Training completed weight saved.
# -------------------data_class:5 completed---------------
# time elapsed:99.40 seconds

# %% [markdown]
# # Resnet Plots

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_curve, roc_auc_score

def plot_loss(allloss):
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    for i in range(3):
        axs[i].plot(np.mean(allloss[f"fold{i+1}"],axis=0)[0], label=f"{fold+1} fold",c='red')
        axs[i].set_title(f'Fold {i+1} Validation Mean Loss')  
        axs[i].set_xlabel('Epochs/fold')
        axs[i].set_ylabel('Loss')
        axs[i].legend()
    plt.tight_layout()  
    plt.show()

def plot_acc(allacc):
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    for i in range(3):
        axs[i].plot(np.mean(allacc[f"fold{i+1}"],axis=0)[0], label=f"{fold+1} fold",c='orange')
        axs[i].set_title(f'Fold {i+1} Validation Mean Accuracy')  
        axs[i].set_xlabel('Epochs/fold')
        axs[i].set_ylabel('Loss')
        axs[i].legend()
    plt.tight_layout()  
    plt.show()

def plot_cm(all_y_true, all_y_pred):
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    for fold in range(3):    
        real = []
        for i in range(len(ally_true[f"fold{fold+1}"])):
            real.extend(ally_true[f"fold{fold+1}"][i][0])
        pred = []
        for i in range(len(ally_pred[f"fold{fold+1}"])):
            pred.extend(ally_pred[f"fold{fold+1}"][i][0])
        cm = confusion_matrix(real, pred)
        ConfusionMatrixDisplay(cm).plot(ax=axs[fold],cmap='Blues',values_format='d')
        axs[fold].set_title(f"Fold {fold+1}")
    plt.tight_layout()
    plt.show()
plot_loss(allloss)
plot_acc(allacc)
plot_cm(ally_true,ally_pred)

# %% [markdown]
# # EfficientNet

# %%
##
import torchvision
efficientnet = torchvision.models.efficientnet_b0(pretrained=True)
efficientnet.classifier[1] = nn.Linear(1280,5)

allloss = {"fold1":[],"fold2":[],"fold3":[]}
allacc = {"fold1":[],"fold2":[],"fold3":[]}
ally_true = {"fold1":[],"fold2":[],"fold3":[]}
ally_pred = {"fold1":[],"fold2":[],"fold3":[]}

metrics = [allloss,allacc,ally_true,ally_pred]

import time
timee = []

best_acc_eff = 0.0
n_classes = 5
for data_idx in range(n_classes):
    s = time.time()
    loss,acc,y_true,y_pred,best_acc_eff = one_vs_rest(efficientnet,"EfficientNet_five",data_idx,best_acc=best_acc_eff)
    print(f"-------------------data_class:{data_idx+1} completed---------------")
    print(f"time elapsed:{time.time()-s:.2f} seconds")
    timee.append(time.time()-s)
    returned = [loss,acc,y_true,y_pred]
    for i,m in enumerate(metrics):
        for fold in range(3):
            m[f"fold{fold+1}"].append(returned[i][f"fold{fold+1}"])
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Fold 1:
# Epoch 1/3 (Training) for EfficientNet_five: 100%|██████████| 59/59 [00:07<00:00,  7.89it/s, acc=0.854, loss=0.809]
# Epoch 1/3 (Validation) for EfficientNet_five: 100%|██████████| 30/30 [00:03<00:00,  8.46it/s, acc=0.946, loss=0.404]
# Model saved to EfficientNet_five_model.pth
# EfficientNet_five weights saved with best accuracy :0.946236559139785
# Epoch 2/3 (Training) for EfficientNet_five: 100%|██████████| 59/59 [00:07<00:00,  7.93it/s, acc=0.983, loss=0.147]
# Epoch 2/3 (Validation) for EfficientNet_five: 100%|██████████| 30/30 [00:03<00:00,  8.59it/s, acc=0.959, loss=0.237]
# Model saved to EfficientNet_five_model.pth
# EfficientNet_five weights saved with best accuracy :0.9591397849462365
# Epoch 3/3 (Training) for EfficientNet_five: 100%|██████████| 59/59 [00:07<00:00,  7.77it/s, acc=0.989, loss=0.0607]
# Epoch 3/3 (Validation) for EfficientNet_five: 100%|██████████| 30/30 [00:03<00:00,  8.71it/s, acc=0.987, loss=0.172]
# Model saved to EfficientNet_five_model.pth
# EfficientNet_five weights saved with best accuracy :0.9870967741935484
# Training completed weight saved.
# Fold 2:
# weights of EfficientNet_five loaded
# Epoch 1/3 (Training) for EfficientNet_five: 100%|██████████| 59/59 [00:07<00:00,  7.92it/s, acc=0.992, loss=0.0397]
# Epoch 1/3 (Validation) for EfficientNet_five: 100%|██████████| 30/30 [00:03<00:00,  8.47it/s, acc=0.994, loss=0.0504]
# Model saved to EfficientNet_five_model.pth
# EfficientNet_five weights saved with best accuracy :0.9935483870967742
# Epoch 2/3 (Training) for EfficientNet_five: 100%|██████████| 59/59 [00:07<00:00,  8.20it/s, acc=1, loss=0.00926]
# Epoch 2/3 (Validation) for EfficientNet_five: 100%|██████████| 30/30 [00:03<00:00,  8.29it/s, acc=0.998, loss=0.0395]
# Model saved to EfficientNet_five_model.pth
# EfficientNet_five weights saved with best accuracy :0.9978494623655914
# Epoch 3/3 (Training) for EfficientNet_five: 100%|██████████| 59/59 [00:07<00:00,  8.22it/s, acc=0.997, loss=0.00906]
# Epoch 3/3 (Validation) for EfficientNet_five: 100%|██████████| 30/30 [00:03<00:00,  8.16it/s, acc=0.991, loss=0.0406]
# Training completed weight saved.
# Fold 3:
# weights of EfficientNet_five loaded
# Epoch 1/3 (Training) for EfficientNet_five: 100%|██████████| 59/59 [00:07<00:00,  8.18it/s, acc=0.994, loss=0.0196]
# Epoch 1/3 (Validation) for EfficientNet_five: 100%|██████████| 30/30 [00:03<00:00,  8.06it/s, acc=1, loss=0.0175]
# Model saved to EfficientNet_five_model.pth
# EfficientNet_five weights saved with best accuracy :1.0
# Epoch 2/3 (Training) for EfficientNet_five: 100%|██████████| 59/59 [00:07<00:00,  8.11it/s, acc=0.997, loss=0.00947]
# Epoch 2/3 (Validation) for EfficientNet_five: 100%|██████████| 30/30 [00:03<00:00,  8.72it/s, acc=0.996, loss=0.0179]
# Epoch 3/3 (Training) for EfficientNet_five: 100%|██████████| 59/59 [00:07<00:00,  7.84it/s, acc=0.997, loss=0.00927]
# Epoch 3/3 (Validation) for EfficientNet_five: 100%|██████████| 30/30 [00:03<00:00,  7.85it/s, acc=0.996, loss=0.0189]
# Training completed weight saved.
# -------------------data_class:1 completed---------------
# time elapsed:101.50 seconds
# Fold 1:
# weights of EfficientNet_five loaded
# Epoch 1/3 (Training) for EfficientNet_five: 100%|██████████| 59/59 [00:07<00:00,  7.54it/s, acc=0.956, loss=0.184]
# Epoch 1/3 (Validation) for EfficientNet_five: 100%|██████████| 30/30 [00:03<00:00,  8.90it/s, acc=0.989, loss=0.0501]
# Epoch 2/3 (Training) for EfficientNet_five: 100%|██████████| 59/59 [00:07<00:00,  7.86it/s, acc=0.991, loss=0.0364]
# Epoch 2/3 (Validation) for EfficientNet_five: 100%|██████████| 30/30 [00:03<00:00,  8.90it/s, acc=0.991, loss=0.0342]
# Epoch 3/3 (Training) for EfficientNet_five: 100%|██████████| 59/59 [00:07<00:00,  7.48it/s, acc=0.997, loss=0.0173]
# Epoch 3/3 (Validation) for EfficientNet_five: 100%|██████████| 30/30 [00:03<00:00,  8.85it/s, acc=0.998, loss=0.0266]
# Training completed weight saved.
# Fold 2:
# weights of EfficientNet_five loaded
# Epoch 1/3 (Training) for EfficientNet_five: 100%|██████████| 59/59 [00:07<00:00,  8.09it/s, acc=0.965, loss=0.131]
# Epoch 1/3 (Validation) for EfficientNet_five: 100%|██████████| 30/30 [00:03<00:00,  8.28it/s, acc=0.957, loss=0.155]
# Epoch 2/3 (Training) for EfficientNet_five: 100%|██████████| 59/59 [00:07<00:00,  8.01it/s, acc=0.991, loss=0.0726]
# Epoch 2/3 (Validation) for EfficientNet_five: 100%|██████████| 30/30 [00:04<00:00,  7.36it/s, acc=0.972, loss=0.084]
# Epoch 3/3 (Training) for EfficientNet_five: 100%|██████████| 59/59 [00:07<00:00,  8.06it/s, acc=0.997, loss=0.0186]
# Epoch 3/3 (Validation) for EfficientNet_five: 100%|██████████| 30/30 [00:03<00:00,  8.27it/s, acc=0.976, loss=0.0769]
# Training completed weight saved.
# Fold 3:
# weights of EfficientNet_five loaded
# Epoch 1/3 (Training) for EfficientNet_five: 100%|██████████| 59/59 [00:07<00:00,  8.07it/s, acc=0.957, loss=0.16]
# Epoch 1/3 (Validation) for EfficientNet_five: 100%|██████████| 30/30 [00:03<00:00,  8
3 (Training) for EfficientNet_five: 100%|██████████| 59/59 [00:07<00:00,  7.87it/s, acc=0.995, loss=0.0178]
# Epoch 2/3 (Validation) for EfficientNet_five: 100%|██████████| 30/30 [00:03<00:00,  8.14it/s, acc=0.996, loss=0.027]
# Epoch 3/3 (Training) for EfficientNet_five: 100%|██████████| 59/59 [00:07<00:00,  7.64it/s, acc=0.999, loss=0.00966]
# Epoch 3/3 (Validation) for EfficientNet_five: 100%|██████████| 30/30 [00:03<00:00,  8.42it/s, acc=0.994, loss=0.0187]
# Training completed weight saved.
# -------------------data_class:5 completed---------------
# time elapsed:103.17 seconds

# %% [markdown]
# # EfficientNet Plots

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_curve, roc_auc_score

def plot_loss(allloss):
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    for i in range(3):
        axs[i].plot(np.mean(allloss[f"fold{i+1}"],axis=0)[0], label=f"{fold+1} fold",c='red')
        axs[i].set_title(f'Fold {i+1} Validation Mean Loss')  
        axs[i].set_xlabel('Epochs/fold')
        axs[i].set_ylabel('Loss')
        axs[i].legend()
    plt.tight_layout()  
    plt.show()

def plot_acc(allacc):
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    for i in range(3):
        axs[i].plot(np.mean(allacc[f"fold{i+1}"],axis=0)[0], label=f"{fold+1} fold",c='orange')
        axs[i].set_title(f'Fold {i+1} Validation Mean Accuracy')  
        axs[i].set_xlabel('Epochs/fold')
        axs[i].set_ylabel('Loss')
        axs[i].legend()
    plt.tight_layout()  
    plt.show()

def plot_cm(all_y_true, all_y_pred):
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    for fold in range(3):    
        real = []
        for i in range(len(ally_true[f"fold{fold+1}"])):
            real.extend(ally_true[f"fold{fold+1}"][i][0])
        pred = []
        for i in range(len(ally_pred[f"fold{fold+1}"])):
            pred.extend(ally_pred[f"fold{fold+1}"][i][0])
        cm = confusion_matrix(real, pred)
        ConfusionMatrixDisplay(cm).plot(ax=axs[fold],cmap='Blues',values_format='d')
        axs[fold].set_title(f"Fold {fold+1}")
    plt.tight_layout()
    plt.show()
plot_loss(allloss)
plot_acc(allacc)
plot_cm(ally_true,ally_pred)

# %% [markdown]
# # CustomModel

# %%
##
allloss = {"fold1":[],"fold2":[],"fold3":[]}
allacc = {"fold1":[],"fold2":[],"fold3":[]}
ally_true = {"fold1":[],"fold2":[],"fold3":[]}
ally_pred = {"fold1":[],"fold2":[],"fold3":[]}

metrics = [allloss,allacc,ally_true,ally_pred]

import time
timec = []

best_acc_cust = 0.0
n_classes = 5
for data_idx in range(n_classes):
    s = time.time()
    loss,acc,y_true,y_pred,best_acc_cust = one_vs_rest(model,"CustomAttModel_five",data_idx,best_acc=best_acc_cust)
    print(f"-------------------data_class:{data_idx+1} completed---------------")
    print(f"time elapsed:{time.time()-s:.2f} seconds")
    timec.append(time.time()-s)
    returned = [loss,acc,y_true,y_pred]
    for i,m in enumerate(metrics):
        for fold in range(3):
            m[f"fold{fold+1}"].append(returned[i][f"fold{fold+1}"])
# Out:
# Fold 1:
# weights of CustomAttModel_five loaded
# Epoch 1/3 (Training) for CustomAttModel_five: 100%|██████████| 59/59 [00:08<00:00,  6.87it/s, acc=0.954, loss=0.182]
# Epoch 1/3 (Validation) for CustomAttModel_five: 100%|██████████| 30/30 [00:03<00:00,  8.50it/s, acc=0.968, loss=0.134]
# Model saved to CustomAttModel_five_model.pth
# CustomAttModel_five weights saved with best accuracy :0.967741935483871
# Epoch 2/3 (Training) for CustomAttModel_five: 100%|██████████| 59/59 [00:09<00:00,  6.45it/s, acc=0.952, loss=0.178]
# Epoch 2/3 (Validation) for CustomAttModel_five: 100%|██████████| 30/30 [00:03<00:00,  8.51it/s, acc=0.968, loss=0.135]
# Epoch 3/3 (Training) for CustomAttModel_five: 100%|██████████| 59/59 [00:08<00:00,  6.70it/s, acc=0.953, loss=0.174]
# Epoch 3/3 (Validation) for CustomAttModel_five: 100%|██████████| 30/30 [00:03<00:00,  8.48it/s, acc=0.968, loss=0.122]
# Training completed weight saved.
# Fold 2:
# weights of CustomAttModel_five loaded
# Epoch 1/3 (Training) for CustomAttModel_five: 100%|██████████| 59/59 [00:08<00:00,  6.85it/s, acc=0.961, loss=0.154]
# Epoch 1/3 (Validation) for CustomAttModel_five: 100%|██████████| 30/30 [00:03<00:00,  7.66it/s, acc=0.951, loss=0.182]
# Epoch 2/3 (Training) for CustomAttModel_five: 100%|██████████| 59/59 [00:08<00:00,  6.95it/s, acc=0.961, loss=0.133]
# Epoch 2/3 (Validation) for CustomAttModel_five: 100%|██████████| 30/30 [00:03<00:00,  7.60it/s, acc=0.877, loss=0.326]
# Epoch 3/3 (Training) for CustomAttModel_five: 100%|██████████| 59/59 [00:08<00:00,  6.88it/s, acc=0.961, loss=0.136]
# Epoch 3/3 (Validation) for CustomAttModel_five: 100%|██████████| 30/30 [00:03<00:00,  8.01it/s, acc=0.953, loss=0.197]
# Training completed weight saved.
# Fold 3:
# weights of CustomAttModel_five loaded
# Epoch 1/3 (Training) for CustomAttModel_five: 100%|██████████| 59/59 [00:08<00:00,  6.77it/s, acc=0.959, loss=0.168]
# Epoch 1/3 (Validation) for CustomAttModel_five: 100%|██████████| 30/30 [00:03<00:00,  8.00it/s, acc=0.94, loss=0.191]
# Epoch 2/3 (Training) for CustomAttModel_five: 100%|██████████| 59/59 [00:08<00:00,  6.95it/s, acc=0.96, loss=0.151]
# Epoch 2/3 (Validation) for CustomAttModel_five: 100%|██████████| 30/30 [00:03<00:00,  7.95it/s, acc=0.953, loss=0.165]
# Epoch 3/3 (Training) for CustomAttModel_five: 100%|██████████| 59/59 [00:08<00:00,  6.84it/s, acc=0.962, loss=0.144]
# Epoch 3/3 (Validation) for CustomAttModel_five: 100%|██████████| 30/30 [00

# weights of CustomAttModel_five loaded
# Epoch 1/3 (Training) for CustomAttModel_five: 100%|██████████| 59/59 [00:08<00:00,  6.64it/s, acc=0.955, loss=0.197]
# Epoch 1/3 (Validation) for CustomAttModel_five: 100%|██████████| 30/30 [00:03<00:00,  8.11it/s, acc=0.961, loss=0.152]
# Epoch 2/3 (Training) for CustomAttModel_five: 100%|██████████| 59/59 [00:08<00:00,  6.76it/s, acc=0.955, loss=0.164]
# Epoch 2/3 (Validation) for CustomAttModel_five: 100%|██████████| 30/30 [00:03<00:00,  8.32it/s, acc=0.961, loss=0.151]
# Epoch 3/3 (Training) for CustomAttModel_five: 100%|██████████| 59/59 [00:08<00:00,  6.64it/s, acc=0.954, loss=0.151]
# Epoch 3/3 (Validation) for CustomAttModel_five: 100%|██████████| 30/30 [00:03<00:00,  7.58it/s, acc=0.955, loss=0.146]
# Training completed weight saved.
# Fold 2:
# weights of CustomAttModel_five loaded
# Epoch 1/3 (Training) for CustomAttModel_five: 100%|██████████| 59/59 [00:08<00:00,  6.93it/s, acc=0.965, loss=0.154]
# Epoch 1/3 (Validation) for CustomAttModel_five: 100%|██████████| 30/30 [00:03<00:00,  8.24it/s, acc=0.942, loss=0.203]
# Epoch 2/3 (Training) for CustomAttModel_five: 100%|██████████| 59/59 [00:08<00:00,  6.85it/s, acc=0.966, loss=0.145]
# Epoch 2/3 (Validation) for CustomAttModel_five: 100%|██████████| 30/30 [00:04<00:00,  7.19it/s, acc=0.942, loss=0.216]
# Epoch 3/3 (Training) for CustomAttModel_five: 100%|██████████| 59/59 [00:08<00:00,  6.67it/s, acc=0.965, loss=0.134]
# Epoch 3/3 (Validation) for CustomAttModel_five: 100%|██████████| 30/30 [00:03<00:00,  7.69it/s, acc=0.927, loss=0.179]
# Training completed weight saved.
# Fold 3:
# weights of CustomAttModel_five loaded
# Epoch 1/3 (Training) for CustomAttModel_five: 100%|██████████| 59/59 [00:08<00:00,  6.73it/s, acc=0.952, loss=0.199]
# Epoch 1/3 (Validation) for CustomAttModel_five: 100%|██████████| 30/30 [00:03<00:00,  8.07it/s, acc=0.968, loss=0.145]
# Epoch 2/3 (Training) for CustomAttModel_five: 100%|██████████| 59/59 [00:08<00:00,  6.90it/s, acc=0.952, loss=0.177]
# Epoch 2/3 (Validation) for CustomAttModel_five: 100%|██████████| 30/30 [00:03<00:00,  7.69it/s, acc=0.968, loss=0.133]
# Epoch 3/3 (Training) for CustomAttModel_five: 100%|██████████| 59/59 [00:08<00:00,  6.81it/s, acc=0.951, loss=0.164]
# Epoch 3/3 (Validation) for CustomAttModel_five: 100%|██████████| 30/30 [00:03<00:00,  8.11it/s, acc=0.968, loss=0.107]
# Training completed weight saved.
# -------------------data_class:5 completed---------------
# time elapsed:115.00 seconds

# %% [markdown]
# # CustomModel Plots

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_curve, roc_auc_score

def plot_loss(allloss):
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    for i in range(3):
        axs[i].plot(np.mean(allloss[f"fold{i+1}"],axis=0)[0], label=f"{fold+1} fold",c='red')
        axs[i].set_title(f'Fold {i+1} Validation Mean Loss')  
        axs[i].set_xlabel('Epochs/fold')
        axs[i].set_ylabel('Loss')
        axs[i].legend()
    plt.tight_layout()  
    plt.show()

def plot_acc(allacc):
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    for i in range(3):
        axs[i].plot(np.mean(allacc[f"fold{i+1}"],axis=0)[0], label=f"{fold+1} fold",c='orange')
        axs[i].set_title(f'Fold {i+1} Validation Mean Accuracy')  
        axs[i].set_xlabel('Epochs/fold')
        axs[i].set_ylabel('Loss')
        axs[i].legend()
    plt.tight_layout()  
    plt.show()

def plot_cm(all_y_true, all_y_pred):
    fig, axs = plt.subplots(1, 3, figsize=(15, 5))
    for fold in range(3):    
        real = []
        for i in range(len(ally_true[f"fold{fold+1}"])):
            real.extend(ally_true[f"fold{fold+1}"][i][0])
        pred = []
        for i in range(len(ally_pred[f"fold{fold+1}"])):
            pred.extend(ally_pred[f"fold{fold+1}"][i][0])
        cm = confusion_matrix(real, pred)
        ConfusionMatrixDisplay(cm).plot(ax=axs[fold],cmap='Blues',values_format='d')
        axs[fold].set_title(f"Fold {fold+1}")
    plt.tight_layout()
    plt.show()
plot_loss(allloss)
plot_acc(allacc)
plot_cm(ally_true,ally_pred)

# %% [markdown]
# # Best Accuracy on Validation

# %%
models = ["resnet", "efficientnet", "custom"]
accuracies = [best_acc_resnet, best_acc_eff, best_acc_cust]

# Define a colormap
colors = ["orange","blue","red"]

plt.figure(figsize=(6, 6))
bars = plt.bar(models, accuracies, color=colors)

plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison of Different Models')

# Adding the accuracy values on top of the bars
for bar, accuracy in zip(bars, accuracies):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.005, f'{accuracy:.2f}', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Time Taken

# %%
models = ["resnet", "efficientnet", "custom"]
time = [np.sum(timer), np.sum(timee), np.sum(timec)]

# Define a colormap
colors = ["orange","blue","red"]

plt.figure(figsize=(6, 6))
bars = plt.bar(models, time, color=colors)

plt.xlabel('Models')
plt.ylabel('Time in Seconds')
plt.title('Time taken for Different Models')

for bar, time in zip(bars, time):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.005, f'{time:.2f}', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Visualising  Neural Nets

# %% [markdown]
# ## Visualising CustomNet Attention Map

# %%
class Attn(Model):
    def __init__(self):
        super().__init__(num_classes=2)
        
    def forward(self, x):
        block1 = self.conv_block1(x)       # /2
        block2 = self.conv_block2(block1)  # /4
        block3 = self.conv_block3(block2)  # /8
        block4 = self.conv_block4(block3)  # /16
        block5 = self.conv_block5(block4)  # /32
        N, __, __, __ = block5.size()
        
        g = self.pool(block5).view(N, 512)
        a1, g1 = self.attn1(block3, block5)
        g_hat = torch.cat((g, g1), dim=1)  # batch_size x C
        out = self.cls(g_hat)
        return a1

model = Attn().to(device)
model.load_state_dict(torch.load(f"CustomAttModel_bi_model.pth"))
# Out:
# <All keys matched successfully>

# %%
random_indices = np.random.randint(0, 90, size=16)

fig, axes = plt.subplots(4, 4, figsize=(16, 8))

# Plot each attention map
for i, ax in enumerate(axes.flatten()):
    with torch.no_grad():
        model.eval()
        img_tensor = temp_data[random_indices[i]][0].unsqueeze(0).to(device)
        attention_map = model(img_tensor).cpu().numpy()
    ax.imshow(attention_map[0][0])


plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualing Convolution Output of Layers

# %%
def layer_viz(model, input_image_path):
    # Load the image and preprocess it
    transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])
    input_image = Image.open(input_image_path)
    input_tensor = transform(input_image).unsqueeze(0).to(device)  # Add batch dimension

    # Set model to evaluation mode
    model.eval()

    # Forward pass to get the output of convolutional layers
    activations = []
    def hook(module, input, output):
        activations.append(output.cpu().numpy())
    hooks = []
    for layer in model.modules():
        if isinstance(layer, torch.nn.Conv2d):
            hooks.append(layer.register_forward_hook(hook))

    # Pass input image through the model
    with torch.no_grad():
        model(input_tensor)
        
    activations = activations[::-1]


    # Remove hooks
    for hook in hooks:
        hook.remove()

    # Plot the activations of each convolutional layer in subplots
    num_layers = len(activations)
    num_cols = min(num_layers, 4)  # Limit the number of columns in subplots
    num_rows = (num_layers - 1) // num_cols + 1
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 5 * num_rows))
    for i, activation in enumerate(activations):
        row_idx = i // num_cols
        col_idx = i % num_cols
        axes[row_idx, col_idx].imshow(activation[0][0].squeeze(), cmap='viridis')
        axes[row_idx, col_idx].set_title(f'Layer {i+1}')
        axes[row_idx, col_idx].axis('off')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Resnet

# %%
resnet = torch.hub.load('pytorch/vision:v0.10.0', 'resnet18', pretrained=True)
resnet.fc = nn.Linear(512,5)
resnet.to(device)
resnet.load_state_dict(torch.load(f"Resnet_five_model.pth"))
# Usage example:
layer_viz(resnet, input_image_path="/kaggle/input/animal-image-dataset-90-different-animals/animals/animals/antelope/02f4b3be2d.jpg")
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0

# %% [markdown]
# # EfficientNet

# %%
efficientnet = torchvision.models.efficientnet_b0(pretrained=True)
efficientnet.classifier[1] = nn.Linear(1280,5)
efficientnet.to(device)
efficientnet.load_state_dict(torch.load("EfficientNet_five_model.pth"))
layer_viz(resnet, input_image_path="/kaggle/input/animal-image-dataset-90-different-animals/animals/animals/antelope/02f4b3be2d.jpg")

# %% [markdown]
# ## CustomModel

# %%
model = Model(2).to(device)
model.load_state_dict(torch.load(f"CustomAttModel_bi_model.pth"))
layer_viz(resnet, input_image_path="/kaggle/input/animal-image-dataset-90-different-animals/animals/animals/antelope/02f4b3be2d.jpg")

# %%
#double descent 
#my pap
